# %%
# %matplotlib notebook

# %%
import calour as ca
import numpy as np
import pandas as pd
from skbio.diversity import beta_diversity
from skbio.stats.ordination import pcoa
from sklearn.metrics import roc_curve, auc
from emperor import Emperor, nbinstall
from calour.training import plot_roc
import matplotlib.pyplot as plt

# %%
exp = ca.read('data/metabolome/features_TSNnorm.txt', 'data/combined_sample_metadata_HFD.txt',
             normalize=100, feature_metadata_file='data/metabolome/annotations_wStandards.txt')

exp = exp.filter_samples('body_habitat', 'UBERON:feces').filter_samples('diet', 'HFD')
# Out:
# 2018-08-24 15:40:51 WARNING These have metadata but do not have data - dropped (343): {'11548.A23.117.14', '11548.A22.115.4', '11548.A22.113.3', '11548.A18.97.17', '11548.A20.107.16', '11548.A18.99.19', '11548.A23.117.17', '11548.A18.99.8', '11548.A19.101.8', '11548.A22.113.19', '11548.A20.105.17', '11548.A23.120.17', '11548.A21.109.12', '11548.A21.110.14', '11548.A22.115.6', '11548.A19.103.6', '11548.A20.108.11', '11548.A22.113.6', '11548.A23.120.3', '11548.A19.101.6', '11548.A22.116.16', '11548.A23.118.12', '11548.A22.115.14', '11548.A18.98.11', '11548.A21.111.11', '11548.A20.108.16', '11548.A18.99.2', '11548.A23.117.19', '11548.A22.115.16', '11548.A20.107.19', '11548.A18.98.4', '11548.A19.101.17', '11548.A21.112.4', '11548.A23.120.18', '11548.A18.98.9', '11548.A21.110.7', '11548.A21.111.16', '11548.A18.99.12', '11548.A23.118.3', '11548.A22.114.19', '11548.A19.103.2', '11548.A18.98.17', '11548.A20.108.13', '11548.A23.120.12', '11548.A18.100.3', '11548.A18.98.7', '11548.A23.120.4', '11548.A23.119.6', '11548.A20.108.14', '11548.A18.97.18', '11548.A18.100.4', '11548.A22.114.3', '11548.A19.102.6', '11548.A22.116.9', '11548.A23.119.4', '11548.A23.119.13', '11548.A22.115.8', '11548.A19.101.13', '11548.A19.104.13', '11548.A22.114.11', '11548.A21.112.13', '11548.A19.101.7', '11548.A22.113.11', '11548.A21.109.18', '11548.A20.107.2', '11548.A22.114.17', '11548.A18.99.7', '11548.A21.112.12', '11548.A21.109.11', '11548.A20.106.14', '11548.A18.99.13', '11548.A22.114.12', '11548.A18.100.17', '11548.A21.109.9', '11548.A21.109.19', '11548.A19.104.4', '11548.A21.111.18', '11548.A22.115.11', '11548.A18.99.14', '11548.A21.112.2', '11548.A22.116.17', '11548.A23.117.3', '11548.A18.99.17', '11548.A23.119.18', '11548.A22.116.6', '11548.A22.116.19', '11548.A22.113.16', '11548.A20.106.3', '11548.A22.114.16', '11548.A19.102.9', '11548.A22.114.4', '11548.A19.101.12', '11548.A21.109.6', '11548.A23.120.9', '11548.A19.104.2', '11548.A19.101.11', '11548.A21.111.4', '11548.A19.104.18', '11548.A20.108.6', '11548.A20.105.16', '11548.A18.98.3', '11548.A21.112.18', '11548.A19.103.8', '11548.A20.108.19', '11548.A20.106.8', '11548.A23.118.6', '11548.A21.110.4', '11548.A21.109.14', '11548.A23.119.14', '11548.A20.107.3', '11548.A19.104.11', '11548.A21.111.13', '11548.A22.115.9', '11548.A19.104.19', '11548.A18.99.3', '11548.A20.105.14', '11548.A21.109.3', '11548.A18.99.18', '11548.A20.106.16', '11548.A23.118.4', '11548.A20.107.6', '11548.A19.101.16', '11548.A22.116.8', '11548.A18.99.4', '11548.A18.100.18', '11548.A20.105.18', '11548.A19.101.4', '11548.A23.118.13', '11548.A20.106.6', '11548.A21.109.13', '11548.A20.106.2', '11548.A18.98.6', '11548.A23.118.19', '11548.A20.105.8', '11548.A21.109.17', '11548.A19.102.8', '11548.A18.98.19', '11548.A21.111.3', '11548.A20.105.12', '11548.A20.106.12', '11548.A20.106.18', '11548.A22.113.2', '11548.A18.97.16', '11548.A18.97.11', '11548.A18.97.9', '11548.A19.102.7', '11548.A22.114.6', '11548.A18.100.2', '11548.A20.106.9', '11548.A20.105.6', '11548.A22.116.12', '11548.A23.117.18', '11548.A23.117.16', '11548.A20.105.13', '11548.A21.110.17', '11548.A21.109.16', '11548.A23.118.9', '11548.A21.110.9', '11548.A23.119.19', '11548.A23.119.9', '11548.A22.114.9', '11548.A21.112.16', '11548.A22.116.13', '11548.A19.103.9', '11548.A21.111.12', '11548.A20.108.3', '11548.A19.101.18', '11548.A23.120.19', '11548.A21.112.6', '11548.A18.97.2', '11548.A23.119.11', '11548.A22.115.12', '11548.A22.115.13', '11548.A20.105.3', '11548.A20.107.11', '11548.A20.106.11', '11548.A18.97.6', '11548.A22.116.2', '11548.A22.115.17', '11548.A19.104.17', '11548.A23.118.18', '11548.A22.114.14', '11548.A20.106.17', '11548.A19.102.4', '11548.A23.117.7', '11548.A21.111.17', '11548.A19.101.2', '11548.A18.97.3', '11548.A19.102.16', '11548.A18.100.9', '11548.A20.106.19', '11548.A19.103.4', '11548.A19.103.11', '11548.A22.116.14', '11548.A20.105.7', '11548.A22.116.18', '11548.A18.100.6', '11548.A23.120.8', '11548.A20.105.19', '11548.A18.98.14', '11548.A18.99.6', '11548.A22.1 ...
# 2018-08-24 15:40:51 WARNING These have data but do not have metadata: {'10422.20.F.2', '11548.A15.87.20', '11548.A15.86.5', '10422.17.F.1', '11548.A15.85.15', '10422.32.F.2', '11548.A15.85.20', '10422.27.F.2', '10422.26.F.1', '10422.29.F.2', '11548.A16.89.15', '11548.A17.94.1', '11548.A17.95.20', '11548.A17.94.5', '11548.A19.102.20', '11548.A16.91.20', '11548.A17.94.20', '11548.A16.92.1', '11548.A15.87.1', '11548.A16.91.15', '10422.31.F.1', '11548.A16.90.20', '10422.18.F.1', '11548.A16.92.10', '11548.A17.95.1', '10422.19.F.1', '10422.28.F.2', '11548.A17.94.10', '10422.25.F.2', '11548.A17.93.15', '11548.A15.87.5', '11548.A15.88.15', '11548.A16.89.20', '11548.A15.86.20', '11548.A17.95.15', '11548.A15.86.10', '11548.A15.88.5', '10422.23.F.11', '10422.23.F.7', '11548.A15.86.15', '10422.30.F.1', '10422.23.F.1', '10422.17.F.2', '11548.A17.96.15', '11548.A16.91.5', '11548.A17.95.5', '10422.30.F.12', '11548.A16.89.1', '11548.A16.90.5', '10422.27.F.1', '11548.A16.90.1', '10422.25.F.1', '11548.A15.87.10', '11548.A15.85.1', '11548.A17.96.10', '11548.A17.96.5', '11548.A16.92.5', '11548.A15.86.1', '11548.A16.89.5', '11548.A17.94.15', '11548.A16.90.15', '11548.A15.88.1', '11548.A17.93.20', '11548.A16.91.10', '10422.27.F.4', '11548.A15.85.10', '11548.A16.90.10', '11548.A15.88.20', '11548.A15.88.10', '11548.A16.92.15', '11548.A16.91.1', '10422.24.F.3', '11548.A17.93.10', '10422.18.F.2', '10422.21.F.1', '11548.A16.89.10', '10422.32.F.13', '11548.A17.93.1', '11548.A16.92.20', '11548.A17.96.20', '11548.A17.96.1', '11548.A17.93.5', '10422.24.F.1', '11548.A17.95.10', '11548.A15.85.5', '10422.26.F.2'}

# %%
exp
# Out:
# Experiment ("features_TSNnorm.txt") with 299 samples, 1889 features

# %% [markdown]
# # PCoA

# %%
bc_dm = beta_diversity("euclidean", exp.data.todense(), validate=False)

# %%
bc_dm.ids = exp.sample_metadata.index

# %%
ordin = pcoa(bc_dm)

# %%
x = (Emperor(ordin, exp.sample_metadata, remote=True)
      .color_by('genotype', colormap='Dark2'))
x
# Out:
# <script type="text/javascript">
#
# if ($("#emperor-css").length == 0){{
#     $("head").append([
#
#         '<link id="emperor-css" rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/css/emperor.css">',
#         '<link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/css/jquery-ui.min.css">',
#         '<link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/css/slick.grid.min.css">',
#         '<link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/css/spectrum.min.css">',
#         '<link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/css/chosen.min.css">',
#         '<link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/css/jquery.contextMenu.min.css">'
#     ]);
# }}
# </script>
#
# <div id='emperor-notebook-0xad507b0d' style="position: relative; width:100%; height:500px;">
#   <div class='loading' style="position: absolute;top: 50%;left: 50%;margin-left: -229px; margin-top: -59px; z-index: 10000;height:118px;width:458px;padding:0px"><img src='https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/img/emperor.png' alt='Emperor resources missing. Expected them to be found in https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files'></div>
# </div>
# </div>
#
# <script type="text/javascript">
# requirejs.config({
# // the left side is the module name, and the right side is the path
# // relative to the baseUrl attribute, do NOT include the .js extension
# 'paths': {
#   /* jQuery */
#   'jquery': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/jquery-2.1.4.min',
#   'jqueryui': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/jquery-ui.min',
#   'jquery_drag': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/jquery.event.drag-2.2.min',
#
#   /* jQuery plugins */
#   'chosen': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/chosen.jquery.min',
#   'spectrum': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/spectrum.min',
#   'position': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/jquery.ui.position.min',
#   'contextmenu': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/jquery.contextMenu.min',
#
#   /* other libraries */
#   'underscore': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/underscore-min',
#   'chroma': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/chroma.min',
#   'filesaver': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/FileSaver.min',
#   'blob': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/Blob',
#   'canvastoblob': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/canvas-toBlob',
#   'd3': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/d3.min',
#
#   /* THREE.js and plugins */
#   'three': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/three.min',
#   'orbitcontrols': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/three.js-plugins/OrbitControls',
#   'projector': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/three.js-plugins/Projector',
#   'svgrenderer': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/three.js-plugins/SVGRenderer',
#   'canvasrenderer': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/three.js-plugins/CanvasRenderer',
#
#   /* SlickGrid */
#   'slickcore': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/slick.core.min',
#   'slickgrid': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/slick.grid.min',
#   'slickformatters': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/slick.editors.min',
#   'slickeditors': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/vendor/js/slick.formatters.min',
#
#   /* Emperor's objects */
#   'util': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/util',
#   'model': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/model',
#   'view': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/view',
#   'controller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/controller',
#   'draw': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/draw',
#   'scene3d': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/sceneplotview3d',
#   'shapes': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/shapes',
#   'animationdirector': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/animate',
#   'trajectory': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/trajectory',
#
#   /* controllers */
#   'abcviewcontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/abc-view-controller',
#   'viewcontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/view-controller',
#   'colorviewcontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/color-view-controller',
#   'visibilitycontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/visibility-controller',
#   'opacityviewcontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/opacity-view-controller',
#   'scaleviewcontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/scale-view-controller',
#   'shapecontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/shape-controller',
#   'axescontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/axes-controller',
#   'animationscontroller': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/animations-controller',
#
#   /* editors */
#   'shape-editor': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/shape-editor',
#   'color-editor': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/color-editor',
#   'scale-editor': 'https://cdn.rawgit.com/biocore/emperor/1.0.0-beta.16/emperor/support_files/js/scale-editor'
#
# },
# /*
#    Libraries that are not AMD compatible need shim to declare their
#    dependencies.
#  */
# 'shim': {
#   'jquery_drag': {
#     'deps': ['jquery', 'jqueryui']
#   },
#   'chosen': {
#     'deps': ['jquery'],
#     'exports': 'jQuery.fn.chosen'
#   },
#   'contextmenu' : {
#     'deps': ['jquery', 'jqueryui', 'position']
#   },
#   'filesaver' : {
#     'deps': ['blob']
#   },
#   'canvastoblob' : {
#     'deps': ['blob']
#   },
#   'slickcore': ['jqueryui'],
#   'slickgrid': ['slickcore', 'jquery_drag', 'slickformatters', 'slickeditors']
# }
# });
#
# requirejs(
# ["jquery", "model", "controller"],
# function($, model, EmperorController) {
#   var DecompositionModel = model.DecompositionModel;
#
#   var div = $('#emperor-notebook-0xad507b0d');
#
#   var data = {"plot": {"decomposition": {"axes_names": ["PC1", "PC2", "PC3", "PC4", "PC5"], "ci": null, "coordinates": [[-0.3344291653226812, 0.1544919361843686, 0.1829924437656672, 0.12519812469884392, -0.17145241172686285], [-0.34788512707541863, -0.08

# %%
exp.sample_metadata.genotype.value_counts()
# Out:
# LDLR KO    182
# ApoE KO    117
# Name: genotype, dtype: int64

# %% [markdown]
# # APOE and LDLR models

# %%
# filtering features if the abundance is less than 'cutoff' in 'fraction' of samples in either 'field'
exp2 = exp.filter_prevalence(field='genotype', cutoff=0.1, fraction=0.1).filter_samples('age', [10, 10.5], 
                                                                                         negate=True)
exp2
# Out:
# Experiment ("features_TSNnorm.txt") with 263 samples, 377 features

# %%
# filter samples not labeled as Apoe or ldlr
exp2 = exp2.filter_samples('genotype', ['ApoE KO','LDLR KO'])

# %%
exp2.sample_metadata.genotype.value_counts()
# Out:
# LDLR KO    170
# ApoE KO     93
# Name: genotype, dtype: int64

# %%
exp2_apoe = exp2.filter_samples('genotype', 'ApoE KO')
exp2_apoe.sample_metadata.exposure_type.value_counts()
# Out:
# Air    48
# IHH    45
# Name: exposure_type, dtype: int64

# %%
exp2_ldlr = exp2.filter_samples('genotype', 'LDLR KO')
exp2_ldlr.sample_metadata.exposure_type.value_counts()
# Out:
# Air    85
# IHH    85
# Name: exposure_type, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RepeatedStratifiedKFold, GroupKFold
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## apoe to ldlr

# %%
it_apoe = exp2_apoe.classify('exposure_type',
                             RandomForestClassifier(n_estimators=500),
                             GroupKFold(5).split(
                                 exp2_apoe.data, exp2_apoe.sample_metadata['exposure_type'], 
                                 exp2_apoe.sample_metadata['mouse_number']))

# %%
res_apoe = next(it_apoe)

# %%
res_apoe.head()
# Out:
#      Air    IHH Y_TRUE            SAMPLE  CV
# 0  0.424  0.576    IHH   11548.A19.101.5   0
# 1  0.174  0.826    IHH  11548.A19.101.10   0
# 2  0.030  0.970    IHH  11548.A19.101.20   0
# 3  0.060  0.940    IHH  11548.A19.101.15   0
# 4  0.868  0.132    Air  11548.A22.113.20   0

# %%
plot_roc(res_apoe, classes=['IHH'], cv=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
clf_apoe = RandomForestClassifier(500, oob_score=True)
clf_apoe.fit(exp2_apoe.data, exp2_apoe.sample_metadata.exposure_type)
clf_apoe.oob_score_
# Out:
# 1.0

# %%
res_apoe2ldlr = pd.DataFrame(clf_apoe.predict_proba(exp2_ldlr.data))
res_apoe2ldlr.columns = clf_apoe.classes_
res_apoe2ldlr['Y_TRUE'] = exp2_ldlr.sample_metadata['exposure_type'].values
res_apoe2ldlr['CV'] = 0

# %%
plot_roc(res_apoe2ldlr, classes=['IHH'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## ldlr to apoe

# %%
it_ldlr = exp2_ldlr.classify('exposure_type', RandomForestClassifier(n_estimators=500),
                             GroupKFold(5).split(
                                 exp2_ldlr.data, exp2_ldlr.sample_metadata['exposure_type'], exp2_ldlr.sample_metadata['mouse_number']))

# %%
res_ldlr = next(it_ldlr)

# %%
res_ldlr.head()
# Out:
#      Air    IHH Y_TRUE         SAMPLE  CV
# 0  0.124  0.876    IHH   10422.17.F.6   0
# 1  0.058  0.942    IHH  10422.17.F.12   0
# 2  0.098  0.902    IHH   10422.17.F.5   0
# 3  0.286  0.714    IHH   10422.17.F.3   0
# 4  0.106  0.894    IHH   10422.17.F.8   0

# %%
plot_roc(res_ldlr, classes=['IHH'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
clf_ldlr = RandomForestClassifier(500, oob_score=True)
clf_ldlr.fit(exp2_ldlr.data, exp2_ldlr.sample_metadata.exposure_type)
clf_ldlr.oob_score_
# Out:
# 0.9647058823529412

# %%
res_ldlr2apoe = pd.DataFrame(clf_ldlr.predict_proba(exp2_apoe.data))
res_ldlr2apoe.columns = clf_ldlr.classes_
res_ldlr2apoe['Y_TRUE'] = exp2_apoe.sample_metadata['exposure_type'].values
res_ldlr2apoe['CV'] = 0

# %%
plot_roc(res_ldlr2apoe, classes=['IHH'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # feature imp

# %%
imp = pd.DataFrame({'apoe': clf_apoe.feature_importances_,
                    'ldlr': clf_ldlr.feature_importances_})

# %%
imp_rank = imp.rank(ascending=False)

# %%
imp.head()
# Out:
#        apoe      ldlr
# 0  0.000933  0.000615
# 1  0.002455  0.000563
# 2  0.000084  0.006543
# 3  0.000000  0.001705
# 4  0.000000  0.000324

# %%
imp_rank.head()
# Out:
#     apoe   ldlr
# 0   90.0  217.0
# 1   58.0  234.0
# 2  241.0   34.0
# 3  323.5   91.0
# 4  323.5  308.0

# %%
plt.scatter(imp.apoe, imp.ldlr)

# %%
plt.scatter(imp_rank.apoe, imp_rank.ldlr)

# %%
exp2.feature_metadata['apoe_imp'] = imp.apoe.values
exp2.feature_metadata['ldlr_imp'] = imp.ldlr.values
exp2.feature_metadata['apoe_imp_rank'] = imp_rank.apoe.values
exp2.feature_metadata['ldlr_imp_rank'] = imp_rank.ldlr.values

# %%
# feature important for both models (in top 50 in both)
n = 50
exp3 = (exp2.filter_by_metadata('ldlr_imp_rank', lambda x: [i < n for i in x], axis=1)
         .filter_by_metadata('apoe_imp_rank', lambda x: [i < n for i in x], axis=1))
(exp3
     .sort_samples('age')
     .sort_samples('mouse_number')
     .sort_samples('exposure_type')
     .sort_samples('genotype')
     .cluster_features()
     .plot(sample_field='exposure_type', barx_fields=['genotype', 'mouse_number', 'cage_number'], gui='jupyter'))
# Out:
# 2018-08-01 13:18:20 WARNING Do you forget to normalize your data? It is required before running this function
# <img src="data:image/png;base64,..." width="640">
# Label(value='0 features are selected')
# HBox(children=(Text(value='-', description='Sample ID', layout=Layout(width='100%'), placeholder='Sample ID'),…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('BarcodeSequence', 'Description', 'LinkerPrimerSe…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('row ID', 'row m/z', 'row retention time', 'Libra…
# HBox(children=(Button(description='print axes ranges', style=ButtonStyle(), tooltip='Print the x axis and y ax…
# HTML(value='no annotation found', layout=Layout(height='100px', overflow_y='auto'))

# %%
import pickle
with open('common-imp-metabs.pkl', 'wb') as f:
    pickle.dump(exp3, f)

# %%
exp3.feature_metadata.columns
# Out:
# Index(['row ID', 'row m/z', 'row retention time', 'LibraryID',
#        'standard_indentification_level_1', '_feature_id', 'apoe_imp',
#        'ldlr_imp', 'apoe_imp_rank', 'ldlr_imp_rank'],
#       dtype='object')

# %%
features = []
for i in exp3.feature_metadata.index:
    df = pd.DataFrame({'abundance': exp3[:, i],
                       'taxonomy': exp3.feature_metadata.loc[i, 'LibraryID'],
                       'standard_BA': exp3.feature_metadata.loc[i, 'standard_indentification_level_1'],
                       'genotype': exp3.sample_metadata['genotype'],
                       'age': exp3.sample_metadata['age'],
                       'exposure_type': exp3.sample_metadata['exposure_type']})
    #df['taxonomy'] = 
    features.append(df)

features = pd.concat(features, axis=0)

features.to_csv('common-imp-metabs.tsv', sep='\t')

# %%
# feature not important for ldlr but in top 100 in apoe
n=100
(exp2.filter_by_metadata('ldlr_imp', lambda x: [i==0 for i in x], axis=1)
     .filter_by_metadata('apoe_imp_rank', lambda x: [i < 100 for i in x], axis=1)
     .sort_samples('age')
     .sort_samples('mouse_number')
     .sort_samples('exposure_type')
     .sort_samples('genotype')
     .cluster_features()
     .plot(sample_field='exposure_type', barx_fields=['genotype', 'mouse_number', 'cage_number'], gui='jupyter'))
# Out:
# 2018-08-01 13:19:10 WARNING Do you forget to normalize your data? It is required before running this function
# <img src="data:image/png;base64,..." width="640">
# Label(value='0 features are selected')
# HBox(children=(Text(value='-', description='Sample ID', layout=Layout(width='100%'), placeholder='Sample ID'),…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('BarcodeSequence', 'Description', 'LinkerPrimerSe…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('row ID', 'row m/z', 'row retention time', 'Libra…
# HBox(children=(Button(description='print axes ranges', style=ButtonStyle(), tooltip='Print the x axis and y ax…
# HTML(value='no annotation found', layout=Layout(height='100px', overflow_y='auto'))

# %%
# feature not important for apoe but in top 50 in ldlr
(exp2.filter_by_metadata('apoe_imp', lambda x: [i==0 for i in x], axis=1)
     .filter_by_metadata('ldlr_imp_rank', lambda x: [i < 50 for i in x], axis=1)
     .sort_samples('age')
     .sort_samples('mouse_number')
     .sort_samples('exposure_type')
     .sort_samples('genotype')
     .cluster_features()
     .plot(sample_field='exposure_type', 
           barx_fields=['genotype', 'mouse_number', 'cage_number'], gui='jupyter'))
# Out:
# 2018-08-01 13:19:25 WARNING Do you forget to normalize your data? It is required before running this function
# <img src="data:image/png;base64,..." width="640">
# Label(value='0 features are selected')
# HBox(children=(Text(value='-', description='Sample ID', layout=Layout(width='100%'), placeholder='Sample ID'),…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('BarcodeSequence', 'Description', 'LinkerPrimerSe…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('row ID', 'row m/z', 'row retention time', 'Libra…
# HBox(children=(Button(description='print axes ranges', style=ButtonStyle(), tooltip='Print the x axis and y ax…
# HTML(value='no annotation found', layout=Layout(height='100px', overflow_y='auto'))

# %% [markdown]
# # diff abundance

# %%
exp2_apoe_diff = exp2_apoe.diff_abundance('exposure_type', val1='Air', val2='IHH', alpha=0.01)
# Out:
# 2018-08-01 13:19:42 WARNING Do you forget to normalize your data? It is required before running this function

# %%
exp2_ldlr_diff = exp2_ldlr.diff_abundance('exposure_type', val1='Air', val2='IHH', alpha=0.01)
# Out:
# 2018-08-01 13:19:42 WARNING Do you forget to normalize your data? It is required before running this function

# %%
fids = set(exp2_apoe_diff.feature_metadata.index) & set(exp2_ldlr_diff.feature_metadata.index)

# %%
len(fids)
# Out:
# 52

# %%
exp2.shape
# Out:
# (263, 377)

# %%
features = []
for i in fids:
    df = pd.DataFrame({'abundance': exp2[:, i],
                       'taxonomy': exp2.feature_metadata.loc[i, 'LibraryID'],
                       'standard_BA': exp2.feature_metadata.loc[i, 'standard_indentification_level_1'],
                       'feature': i,
                       'genotype': exp2.sample_metadata['genotype'],
                       'age': exp2.sample_metadata['age'],
                       'exposure_type': exp2.sample_metadata['exposure_type']})
    #df['taxonomy'] = 
    features.append(df)

features = pd.concat(features, axis=0)

features.to_csv('common-diff-metabs.tsv', sep='\t')

# %%
from sklearn.metrics import roc_auc_score

# %%
highpred = []
for i in fids:
    taxon = exp2_apoe.feature_metadata.loc[i, 'LibraryID']
    apoe_score = exp2_apoe[:, i]
    apoe_true = exp2_apoe.sample_metadata['exposure_type'].values == 'IHH'
    a = roc_auc_score(apoe_true, apoe_score)
    if a < 0.5:
        a = 1 - a
    t1 = a
    print('-------')
    print(taxon)
    print(i)
    print('APOE: {:.3f}'.format(a))
    ldlr_score = exp2_ldlr[:, i]
    ldlr_true = exp2_ldlr.sample_metadata['exposure_type'].values == 'IHH'
    a = roc_auc_score(ldlr_true, ldlr_score)
    if a < 0.5:
        a = 1 - a
    t2 = a
    print('LDLR: {:.3f}'.format(a))
    
    # features with greater than 80% accuracy in both models
    if t1>0.75 and t2>0.75:
        highpred.append(i)
# Out:
# -------
# cis-Vaccenic acid
# 265.25244007223137_5.432108840227089
# APOE: 0.971
# LDLR: 0.777
# -------
# nan
# 601.5399281469334_5.45405833333333
# APOE: 0.762
# LDLR: 0.771
# -------
# nan
# 589.30170307438_3.7674697944593385
# APOE: 0.732
# LDLR: 0.649
# -------
# nan
# 391.2843719708507_4.369248333333332
# APOE: 0.803
# LDLR: 0.735
# -------
# nan
# 389.2690331387742_3.437795402298853
# APOE: 0.871
# LDLR: 0.804
# -------
# Spectral Match to Cholic acid from NIST14
# 373.2737632068537_3.6807178630363
# APOE: 0.859
# LDLR: 0.719
# -------
# nan
# 374.27706481344507_3.9006440359477117
# APOE: 0.752
# LDLR: 0.744
# -------
# Methyl 12-hydroxystearate
# 297.27825689035825_5.705698658536578
# APOE: 0.971
# LDLR: 0.689
# -------
# .beta.-Muricholic acid
# 373.2738491153533_3.899919847020934
# APOE: 0.733
# LDLR: 0.731
# -------
# nan
# 326.37793168777256_5.5902060067681925
# APOE: 0.738
# LDLR: 0.741
# -------
# .beta.-Muricholic acid
# 373.2738348512753_3.8372961569579247
# APOE: 0.796
# LDLR: 0.782
# -------
# nan
# 376.2924729358175_4.740066617790812
# APOE: 0.741
# LDLR: 0.862
# -------
# nan
# 514.283968153228_3.3051131999999996
# APOE: 0.893
# LDLR: 0.804
# -------
# trans-Vaccenic acid
# 283.2629498309951_5.430859365079369
# APOE: 0.972
# LDLR: 0.774
# -------
# nan
# 596.255578999257_3.2703611531986527
# APOE: 0.753
# LDLR: 0.635
# -------
# nan
# 423.2744890715284_4.29798541001065
# APOE: 0.920
# LDLR: 0.932
# -------
# Spectral Match to 12-Ketodeoxycholic acid from NIST14
# 391.28440813423026_3.83471722090261
# APOE: 0.850
# LDLR: 0.740
# -------
# Taurocholic acid
# 498.2885969831677_3.5747786131996655
# APOE: 0.964
# LDLR: 0.739
# -------
# nan
# 594.2399187508345_2.941121104536488
# APOE: 0.755
# LDLR: 0.667
# -------
# nan
# 533.32710813091_3.16582487046632
# APOE: 0.969
# LDLR: 0.686
# -------
# nan
# 389.2691196723436_3.383737479270316
# APOE: 0.922
# LDLR: 0.879
# -------
# Spectral Match to Taurocholic acid from NIST14
# 516.300422276808_3.5346080964685593
# APOE: 0.963
# LDLR: 0.824
# -------
# nan
# 407.2793260908103_3.6924033502968627
# APOE: 0.762
# LDLR: 0.883
# -------
# nan
# 589.3019805823072_3.714467548500879
# APOE: 0.823
# LDLR: 0.671
# -------
# nan
# 533.3268329649845_3.536782531194295
# APOE: 0.965
# LDLR: 0.837
# -------
# cis-9-Hexadecenoic acid
# 255.2317783582418_5.1814566985645945
# APOE: 0.978
# LDLR: 0.751
# -------
# nan
# 568.3396247335379_5.054229002624673
# APOE: 0.995
# LDLR: 0.777
# -------
# nan
# 374.2771151341289_3.8368078358208924
# APOE: 0.789
# LDLR: 0.785
# -------
# MoNA:790553 Linoleic acid
# 281.24729224771505_5.287591349206345
# APOE: 0.965
# LDLR: 0.693
# -------
# nan
# 593.3330625900207_4.503197092013891
# APOE: 0.692
# LDLR: 0.645
# -------
# nan
# 324.28986215556387_5.433176666666667
# APOE: 0.964
# LDLR: 0.771
# -------
# Spectral Match to Benzyldodecyldimethylammonium from NIST14
# 304.2993572401259_5.121302585521083
# APOE: 0.744
# LDLR: 0.892
# -------
# Spectral Match to Taurocholic acid from NIST14
# 516.3001954425159_3.6121693593314776
# APOE: 0.807
# LDLR: 0.832
# -------
# Spectral Match to Benzyltetradecyldimethylammonium from NIST14
# 332.3307817246258_5.3103554720133594
# APOE: 0.750
# LDLR: 0.871
# -------
# Spectral Match to Cholic acid from NIST14
# 355.26338080430236_3.96542493887531
# APOE: 0.769
# LDLR: 0.693
# -------
# Taurocholic acid
# 516.2998568826378_3.2370200341005964
# APOE: 0.751
# LDLR: 0.724
# -------
# Spectral Match to Cholic acid from NIST14
# 355.2633984884364_3.811552948402946
# APOE: 0.865
# LDLR: 0.826
# -------
# nan
# 408.3118484055009_4.670038311688313
# APOE: 0.750
# LDLR: 0.650
# -------
# nan
# 358.28219024838404_4.7314112935323385
# APOE: 0.696
# LDLR: 0.884
# -------
# Spectral Match to Cholic acid from NIST14
# 817.5826237288574_3.8388936842105252
# APOE: 0.718
# LDLR: 0.711
# -------
# nan
# 506.27911240204685_3.7126306003584237
# APOE: 0.823
# LDLR: 0.847
# -------
# nan
# 392.28736166242135_4.667996314102565
# APOE: 0.739
# LDLR: 0.720
# -------
# Taurocholic acid
# 498.28847330017254_3.631775063613232
# APOE: 0.978
# LDLR: 0.745
# -------
# Phytosphingosine
# 318.30021103146754_4.875661716171619
# APOE: 0.941
# LDLR: 0.670
# -------
# nan
# 544.3401500596398_5.073365748031497
# APOE: 0.985
# LDLR: 0.743
# -------
# Spectral Match to Phe-Pro from NIST14
# 263.13956123221345_1.975692424242424
# APOE: 0.699
# LDLR: 0.675
# -------
# nan
# 506.27907974349694_3.788732373472948
# APOE: 0.730
# LDLR: 0.893
# -------
# Spectral Match to Cholic acid from NIST14
# 426.32176106573894_3.835625839793279
# APOE: 0.853
# LDLR: 0.704
# -------
# nan
# 817.5822893341162_4.2090098459846
# APOE: 0.781
# LDLR: 0.687
# -------
# Spectral Match to 12-Ketodeoxycholic acid from NIST14
# 391.2844444023548_4.6659394695170215
# APOE: 0.739
# LDLR: 0.731
# -------
# 1-Oleoyl-2-palmitoyl-sn-glycero-3-phosphocholine
# 760.5845892555183_7.696892828282829
# APOE: 0.837
# LDLR: 0.608
# -------
# nan
# 407.279362595115_3.601989730639734
# APOE: 0.831
# LDLR: 0.879

# %%
len(highpred)
# Out:
# 20

# %%
exp2_com = exp2.filter_ids(highpred,
                           axis=1)

# %%
(exp2_com
     .sort_samples('age')
     .sort_samples('mouse_number')
     .sort_samples('exposure_type')
     .sort_samples('genotype')
     #.cluster_features()
     .plot(sample_field='exposure_type', barx_fields=['genotype', 'mouse_number', 'cage_number'], 
           gui='jupyter'))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Label(value='0 features are selected')
# HBox(children=(Text(value='-', description='Sample ID', layout=Layout(width='100%'), placeholder='Sample ID'),…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('BarcodeSequence', 'Description', 'LinkerPrimerSe…
# HBox(children=(Dropdown(layout=Layout(width='20%'), options=('row ID', 'row m/z', 'row retention time', 'Libra…
# HBox(children=(Button(description='print axes ranges', style=ButtonStyle(), tooltip='Print the x axis and y ax…
# HTML(value='no annotation found', layout=Layout(height='100px', overflow_y='auto'))

# %% [markdown]
# # roc curvse

# %%
from matplotlib import pyplot as plt
fig_apoe, ax_apoe = plt.subplots()
ax_apoe.set_aspect('equal')

fids_apoe = []
auc_apoe = []
for i in exp2_apoe.feature_metadata.index:
    apoe_score = exp2_apoe[:, i]
    apoe_true = exp2_apoe.sample_metadata['exposure_type'].values == 'IHH'
    fpr, tpr, thresholds = roc_curve(apoe_true, apoe_score)
    a = auc(fpr, tpr)
    if a < 0.5:
        a = 1-a
    if a > 0.75:
        fids_apoe.append(i)
        auc_apoe.append(a)
    ax_apoe.plot(np.insert(fpr, 0, 0), np.insert(tpr, 0, 0), lw=0.7, color='gray', alpha=0.2)

ax_apoe.plot([0, 1], [0, 1], linestyle='-', lw=1, color='black', alpha=.9)
ax_apoe.set_xlim(-0.05, 1.05)
ax_apoe.set_ylim(-0.05, 1.05)
ax_apoe.set_xlabel('False Positive Rate')
ax_apoe.set_ylabel('True Positive Rate')
ax_apoe.set_title('APOE KO', y=1.08)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1.08,'APOE KO')

# %%
from matplotlib import pyplot as plt
fig_ldlr, ax_ldlr = plt.subplots()
ax_ldlr.set_aspect('equal')
fids_ldlr = []
auc_ldlr = []
for i in exp2_ldlr.feature_metadata.index:
    ldlr_score = exp2_ldlr[:, i]
    ldlr_true = exp2_ldlr.sample_metadata['exposure_type'].values == 'IHH'
    fpr, tpr, thresholds = roc_curve(ldlr_true, ldlr_score)
    a = auc(fpr, tpr)
    if a < 0.5:
        a = 1-a
    if a > 0.75:
        fids_ldlr.append(i)
        auc_ldlr.append(a)
    ax_ldlr.plot(np.insert(fpr, 0, 0), np.insert(tpr, 0, 0), lw=0.7, color='gray', alpha=0.3)

ax_ldlr.plot([0, 1], [0, 1], linestyle='-', lw=1, color='black', alpha=.9)
ax_ldlr.set_xlim(-0.05, 1.05)
ax_ldlr.set_ylim(-0.05, 1.05)
ax_ldlr.set_xlabel('False Positive Rate')
ax_ldlr.set_ylabel('True Positive Rate')
ax_ldlr.set_title('LDLR KO', y=1.08)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1.08,'LDLR KO')

# %%
exp2.feature_metadata.head()
# Out:
#                                        row ID     row m/z  row retention time  \
# #featureID
# 110.02020789262785_7.81588739061257         1  110.020208            7.815887
# 496.3400991541585_5.156902118305356         2  496.340099            5.156902
# 357.2789208085304_4.965391768541157         3  357.278921            4.965392
# 373.2738491153533_3.899919847020934         4  373.273849            3.899920
# 373.27386451947183_3.9615752818035452       5  373.273865            3.961575
#
#                                                                                LibraryID  \
# #featureID
# 110.02020789262785_7.81588739061257                                                  NaN
# 496.3400991541585_5.156902118305356              1-Palmitoyl-sn-glycero-3-phosphocholine
# 357.2789208085304_4.965391768541157    Spectral Match to Chenodeoxycholic acid from N...
# 373.2738491153533_3.899919847020934                               .beta.-Muricholic acid
# 373.27386451947183_3.9615752818035452                             .beta.-Muricholic acid
#
#                                       standard_indentification_level_1  \
# #featureID
# 110.02020789262785_7.81588739061257                                NaN
# 496.3400991541585_5.156902118305356                                NaN
# 357.2789208085304_4.965391768541157                   Deoxycholic acid
# 373.2738491153533_3.899919847020934                  a-Muricholic acid
# 373.27386451947183_3.9615752818035452                b-Muricholic acid
#
#                                                                  _feature_id
# #featureID
# 110.02020789262785_7.81588739061257      110.02020789262785_7.81588739061257
# 496.3400991541585_5.156902118305356      496.3400991541585_5.156902118305356
# 357.2789208085304_4.965391768541157      357.2789208085304_4.965391768541157
# 373.2738491153533_3.899919847020934      373.2738491153533_3.899919847020934
# 373.27386451947183_3.9615752818035452  373.27386451947183_3.9615752818035452

# %%
df1 = pd.DataFrame({'auc': auc_apoe, 'id': fids_apoe})
df2 = pd.DataFrame({'auc': auc_ldlr, 'id': fids_ldlr})

df = pd.merge(df1, df2, 'inner',  left_on='id', right_on='id', suffixes=('_ApoE', '_LDLR'))
df['sum_auc'] = df['auc_ApoE'] + df['auc_LDLR']
df['annot'] = exp2.feature_metadata.loc[df['id'], 'LibraryID'].values
df['annot2'] = exp2.feature_metadata.loc[df['id'], 'standard_indentification_level_1'].values
df.set_index('id', inplace=True)
df.sort_values('sum_auc', ascending=False, kind='mergesort', inplace=True)
df.sort_values('annot', ascending=False, kind='mergesort', inplace=True)

# %%
df
# Out:
#                                        auc_ApoE  auc_LDLR   sum_auc  \
# id
# 283.2629498309951_5.430859365079369    0.971759  0.774118  1.745877
# 265.25244007223137_5.432108840227089   0.970833  0.776609  1.747442
# 255.2317783582418_5.1814566985645945   0.978241  0.751280  1.729521
# 516.300422276808_3.5346080964685593    0.962500  0.823806  1.786306
# 516.3001954425159_3.6121693593314776   0.806944  0.831557  1.638502
# 355.2633984884364_3.811552948402946    0.864815  0.826436  1.691251
# 332.3307817246258_5.3103554720133594   0.750463  0.871003  1.621466
# 373.2738348512753_3.8372961569579247   0.796296  0.782007  1.578303
# 423.2744890715284_4.29798541001065     0.919907  0.932318  1.852226
# 533.3268329649845_3.536782531194295    0.965046  0.837370  1.802417
# 389.2691196723436_3.383737479270316    0.922222  0.878616  1.800838
# 568.3396247335379_5.054229002624673    0.994907  0.776609  1.771516
# 324.28986215556387_5.433176666666667   0.963889  0.770934  1.734823
# 407.279362595115_3.601989730639734     0.831019  0.878616  1.709634
# 514.283968153228_3.3051131999999996    0.893056  0.803737  1.696793
# 389.2690331387742_3.437795402298853    0.871296  0.804014  1.675310
# 506.27911240204685_3.7126306003584237  0.823148  0.846644  1.669792
# 407.2793260908103_3.6924033502968627   0.762037  0.883183  1.645220
# 374.2771151341289_3.8368078358208924   0.788889  0.784913  1.573802
# 601.5399281469334_5.45405833333333     0.761806  0.771349  1.533155
#
#                                                                                    annot  \
# id
# 283.2629498309951_5.430859365079369                                  trans-Vaccenic acid
# 265.25244007223137_5.432108840227089                                   cis-Vaccenic acid
# 255.2317783582418_5.1814566985645945                             cis-9-Hexadecenoic acid
# 516.300422276808_3.5346080964685593       Spectral Match to Taurocholic acid from NIST14
# 516.3001954425159_3.6121693593314776      Spectral Match to Taurocholic acid from NIST14
# 355.2633984884364_3.811552948402946            Spectral Match to Cholic acid from NIST14
# 332.3307817246258_5.3103554720133594   Spectral Match to Benzyltetradecyldimethylammo...
# 373.2738348512753_3.8372961569579247                              .beta.-Muricholic acid
# 423.2744890715284_4.29798541001065                                                   NaN
# 533.3268329649845_3.536782531194295                                                  NaN
# 389.2691196723436_3.383737479270316                                                  NaN
# 568.3396247335379_5.054229002624673                                                  NaN
# 324.28986215556387_5.433176666666667                                                 NaN
# 407.279362595115_3.601989730639734                                                   NaN
# 514.283968153228_3.3051131999999996                                                  NaN
# 389.2690331387742_3.437795402298853                                                  NaN
# 506.27911240204685_3.7126306003584237                                                NaN
# 407.2793260908103_3.6924033502968627                                                 NaN
# 374.2771151341289_3.8368078358208924                                                 NaN
# 601.5399281469334_5.45405833333333                                                   NaN
#
#                                                   annot2
# id
# 283.2629498309951_5.430859365079369                  NaN
# 265.25244007223137_5.432108840227089                 NaN
# 255.2317783582418_5.1814566985645945                 NaN
# 516.300422276808_3.5346080964685593                  NaN
# 516.3001954425159_3.6121693593314776                 NaN
# 355.2633984884364_3.811552948402946    a-Muricholic acid
# 332.3307817246258_5.3103554720133594                 NaN
# 373.2738348512753_3.8372961569579247   a-Muricholic acid
# 423.2744890715284_4.29798541001065                   NaN
# 533.3268329649845_3.536782531194295                  NaN
# 389.2691196723436_3.383737479270316                  NaN
# 568.3396247335379_5.054229002624673                  NaN
# 324.28986215556387_5.433176666666667                 NaN
# 407.279362595115_3.601989730639734                   NaN
# 514.283968153228_3.3051131999999996                  NaN
# 389.2690331387742_3.437795402298853                  NaN
# 506.27911240204685_3.7126306003584237                NaN
# 407.2793260908103_3.6924033502968627                 NaN
# 374.2771151341289_3.8368078358208924                 NaN
# 601.5399281469334_5.45405833333333                   NaN

# %%
df.to_csv('metabolites.tsv', sep='\t')

# %%
row1, row2 = df.iloc[1].copy(), df.iloc[5].copy()
df.iloc[1],df.iloc[5] = row2,row1

# %%
df['annot'][pd.notnull(df['annot2'])] = df['annot2']
df
# Out:
# /Users/zech/miniconda3/envs/calour/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                                        auc_ApoE  auc_LDLR   sum_auc  \
# id
# 283.2629498309951_5.430859365079369    0.971759  0.774118  1.745877
# 265.25244007223137_5.432108840227089   0.970833  0.776609  1.747442
# 255.2317783582418_5.1814566985645945   0.978241  0.751280  1.729521
# 516.300422276808_3.5346080964685593    0.962500  0.823806  1.786306
# 516.3001954425159_3.6121693593314776   0.806944  0.831557  1.638502
# 355.2633984884364_3.811552948402946    0.864815  0.826436  1.691251
# 332.3307817246258_5.3103554720133594   0.750463  0.871003  1.621466
# 373.2738348512753_3.8372961569579247   0.796296  0.782007  1.578303
# 423.2744890715284_4.29798541001065     0.919907  0.932318  1.852226
# 533.3268329649845_3.536782531194295    0.965046  0.837370  1.802417
# 389.2691196723436_3.383737479270316    0.922222  0.878616  1.800838
# 568.3396247335379_5.054229002624673    0.994907  0.776609  1.771516
# 324.28986215556387_5.433176666666667   0.963889  0.770934  1.734823
# 407.279362595115_3.601989730639734     0.831019  0.878616  1.709634
# 514.283968153228_3.3051131999999996    0.893056  0.803737  1.696793
# 389.2690331387742_3.437795402298853    0.871296  0.804014  1.675310
# 506.27911240204685_3.7126306003584237  0.823148  0.846644  1.669792
# 407.2793260908103_3.6924033502968627   0.762037  0.883183  1.645220
# 374.2771151341289_3.8368078358208924   0.788889  0.784913  1.573802
# 601.5399281469334_5.45405833333333     0.761806  0.771349  1.533155
#
#                                                                                    annot  \
# id
# 283.2629498309951_5.430859365079369                                  trans-Vaccenic acid
# 265.25244007223137_5.432108840227089                                   cis-Vaccenic acid
# 255.2317783582418_5.1814566985645945                             cis-9-Hexadecenoic acid
# 516.300422276808_3.5346080964685593       Spectral Match to Taurocholic acid from NIST14
# 516.3001954425159_3.6121693593314776      Spectral Match to Taurocholic acid from NIST14
# 355.2633984884364_3.811552948402946                                    a-Muricholic acid
# 332.3307817246258_5.3103554720133594   Spectral Match to Benzyltetradecyldimethylammo...
# 373.2738348512753_3.8372961569579247                                   a-Muricholic acid
# 423.2744890715284_4.29798541001065                                                   NaN
# 533.3268329649845_3.536782531194295                                                  NaN
# 389.2691196723436_3.383737479270316                                                  NaN
# 568.3396247335379_5.054229002624673                                                  NaN
# 324.28986215556387_5.433176666666667                                                 NaN
# 407.279362595115_3.601989730639734                                                   NaN
# 514.283968153228_3.3051131999999996                                                  NaN
# 389.2690331387742_3.437795402298853                                                  NaN
# 506.27911240204685_3.7126306003584237                                                NaN
# 407.2793260908103_3.6924033502968627                                                 NaN
# 374.2771151341289_3.8368078358208924                                                 NaN
# 601.5399281469334_5.45405833333333                                                   NaN
#
#                                                   annot2
# id
# 283.2629498309951_5.430859365079369                  NaN
# 265.25244007223137_5.432108840227089                 NaN
# 255.2317783582418_5.1814566985645945                 NaN
# 516.300422276808_3.5346080964685593                  NaN
# 516.3001954425159_3.6121693593314776                 NaN
# 355.2633984884364_3.811552948402946    a-Muricholic acid
# 332.3307817246258_5.3103554720133594                 NaN
# 373.2738348512753_3.8372961569579247   a-Muricholic acid
# 423.2744890715284_4.29798541001065                   NaN
# 533.3268329649845_3.536782531194295                  NaN
# 389.2691196723436_3.383737479270316                  NaN
# 568.3396247335379_5.054229002624673                  NaN
# 324.28986215556387_5.433176666666667                 NaN
# 407.279362595115_3.601989730639734                   NaN
# 514.283968153228_3.3051131999999996                  NaN
# 389.2690331387742_3.437795402298853                  NaN
# 506.27911240204685_3.7126306003584237                NaN
# 407.2793260908103_3.6924033502968627                 NaN
# 374.2771151341289_3.8368078358208924                 NaN
# 601.5399281469334_5.45405833333333                   NaN

# %%
fids = list(set(fids_apoe) & set(fids_ldlr))

# %%
fids.sort()

# %%
len(fids)
# Out:
# 20

# %%
print(fids)
# Out:
# ['255.2317783582418_5.1814566985645945', '265.25244007223137_5.432108840227089', '283.2629498309951_5.430859365079369', '324.28986215556387_5.433176666666667', '332.3307817246258_5.3103554720133594', '355.2633984884364_3.811552948402946', '373.2738348512753_3.8372961569579247', '374.2771151341289_3.8368078358208924', '389.2690331387742_3.437795402298853', '389.2691196723436_3.383737479270316', '407.2793260908103_3.6924033502968627', '407.279362595115_3.601989730639734', '423.2744890715284_4.29798541001065', '506.27911240204685_3.7126306003584237', '514.283968153228_3.3051131999999996', '516.3001954425159_3.6121693593314776', '516.300422276808_3.5346080964685593', '533.3268329649845_3.536782531194295', '568.3396247335379_5.054229002624673', '601.5399281469334_5.45405833333333']

# %%
exp2_apoe[:,fids[4]] > 0
# Out:
# array([ True,  True, False,  True, False, False,  True, False,  True,
#        False,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True, False, False,  True, False,  True,
#         True, False, False,  True, False,  True, False,  True,  True,
#        False, False,  True,  True,  True,  True, False,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False])

# %%
(exp2_ldlr.filter_ids(fids[4:5])
      .sort_samples('age')
     .sort_samples('mouse_number')
     .sort_samples('exposure_type')
     .sort_samples('genotype')
         .plot(sample_field='exposure_type', 
           barx_fields=['genotype', 'mouse_number', 'cage_number'], gui='jupyter', clim=[0, 0.2]))
# Out:
# <img src="data:image/png;base64,..." width="640">
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget

# %%
(exp2_apoe.filter_ids(fids[4:5])
      .sort_samples('age')
     .sort_samples('mouse_number')
     .sort_samples('exposure_type')
     .sort_samples('genotype')
         .plot(sample_field='exposure_type', 
           barx_fields=['genotype', 'mouse_number', 'cage_number'], gui='jupyter'))
# Out:
# <img src="data:image/png;base64,..." width="640">
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget

# %%
exp2.feature_metadata.head()
# Out:
#                                        row ID     row m/z  row retention time  \
# #featureID
# 110.02020789262785_7.81588739061257         1  110.020208            7.815887
# 496.3400991541585_5.156902118305356         2  496.340099            5.156902
# 357.2789208085304_4.965391768541157         3  357.278921            4.965392
# 373.2738491153533_3.899919847020934         4  373.273849            3.899920
# 373.27386451947183_3.9615752818035452       5  373.273865            3.961575
#
#                                                                                LibraryID  \
# #featureID
# 110.02020789262785_7.81588739061257                                                  NaN
# 496.3400991541585_5.156902118305356              1-Palmitoyl-sn-glycero-3-phosphocholine
# 357.2789208085304_4.965391768541157    Spectral Match to Chenodeoxycholic acid from N...
# 373.2738491153533_3.899919847020934                               .beta.-Muricholic acid
# 373.27386451947183_3.9615752818035452                             .beta.-Muricholic acid
#
#                                       standard_indentification_level_1  \
# #featureID
# 110.02020789262785_7.81588739061257                                NaN
# 496.3400991541585_5.156902118305356                                NaN
# 357.2789208085304_4.965391768541157                   Deoxycholic acid
# 373.2738491153533_3.899919847020934                  a-Muricholic acid
# 373.27386451947183_3.9615752818035452                b-Muricholic acid
#
#                                                                  _feature_id
# #featureID
# 110.02020789262785_7.81588739061257      110.02020789262785_7.81588739061257
# 496.3400991541585_5.156902118305356      496.3400991541585_5.156902118305356
# 357.2789208085304_4.965391768541157      357.2789208085304_4.965391768541157
# 373.2738491153533_3.899919847020934      373.2738491153533_3.899919847020934
# 373.27386451947183_3.9615752818035452  373.27386451947183_3.9615752818035452

# %%
features = []
for n, i in enumerate(df.index, 1):
    annot = df.loc[i, 'annot']
    if isinstance(annot, float) and np.isnan(annot):
        annot = '%f_%f' % (exp2.feature_metadata.loc[i, 'row m/z'], exp2.feature_metadata.loc[i, 'row retention time'])
    df_ = pd.DataFrame({'abundance': exp2[:, i],
                       'taxonomy': 'metabolite %d: ' % n + annot,
                       'feature': i,
                       'genotype': exp2.sample_metadata['genotype'],
                       'age': exp2.sample_metadata['age'],
                       'exposure_type': exp2.sample_metadata['exposure_type']})
    features.append(df_)

features = pd.concat(features, axis=0)

features.to_csv('common-imp-metabolites2.tsv', sep='\t')

# %%
for n, i in enumerate(df.index, 1):
    apoe_score = exp2_apoe[:, i]
    apoe_true = exp2_apoe.sample_metadata['exposure_type'].values == 'IHH'
    fpr, tpr, thresholds = roc_curve(apoe_true, apoe_score)
    a = auc(fpr, tpr)
    if a < 0.5:
        a = 1-a
    if n > 2:
        #ax_apoe.plot(np.insert(fpr, 0, 0), np.insert(tpr, 0, 0), lw=3, color='black', alpha=0.5)
        pass
    else:
        ax_apoe.plot(np.insert(fpr, 0, 0), np.insert(tpr, 0, 0), lw=3, color=plt.cm.tab10.colors[n-1], label='metabolite %d (%.2f)' % (n, a))
ax_apoe.legend(bbox_to_anchor=(0.0, 1.01), ncol=2, borderaxespad=0, frameon=False, loc="lower left")
fig_apoe.tight_layout()

# %%
for n, i in enumerate(df.index, 1):
    ldlr_score = exp2_ldlr[:, i]
    ldlr_true = exp2_ldlr.sample_metadata['exposure_type'].values == 'IHH'
    fpr, tpr, thresholds = roc_curve(ldlr_true, ldlr_score)
    a = auc(fpr, tpr)
    if a < 0.5:
        a = 1-a
    if n > 2:
        #ax_ldlr.plot(np.insert(fpr, 0, 0), np.insert(tpr, 0, 0), lw=3, color='black', alpha=0.5)
        pass
    else:
        ax_ldlr.plot(np.insert(fpr, 0, 0), np.insert(tpr, 0, 0), lw=3, color=plt.cm.tab10.colors[n-1], label='metabolite %d (%.2f)' % (n, a))
ax_ldlr.legend(bbox_to_anchor=(0.0, 1.01), ncol=2, borderaxespad=0, frameon=False, loc="lower left")
fig_ldlr.tight_layout()

# %%
from matplotlib.backends.backend_pdf import PdfPages

with PdfPages('roc-metabites2.pdf') as pdf:
    pdf.savefig(fig_apoe)
    pdf.savefig(fig_ldlr)

# %%
exp2_apoe.feature_metadata.head()
# Out:
#                                        row ID     row m/z  row retention time  \
# #featureID
# 110.02020789262785_7.81588739061257         1  110.020208            7.815887
# 496.3400991541585_5.156902118305356         2  496.340099            5.156902
# 357.2789208085304_4.965391768541157         3  357.278921            4.965392
# 373.2738491153533_3.899919847020934         4  373.273849            3.899920
# 373.27386451947183_3.9615752818035452       5  373.273865            3.961575
#
#                                                                                LibraryID  \
# #featureID
# 110.02020789262785_7.81588739061257                                                  NaN
# 496.3400991541585_5.156902118305356              1-Palmitoyl-sn-glycero-3-phosphocholine
# 357.2789208085304_4.965391768541157    Spectral Match to Chenodeoxycholic acid from N...
# 373.2738491153533_3.899919847020934                               .beta.-Muricholic acid
# 373.27386451947183_3.9615752818035452                             .beta.-Muricholic acid
#
#                                       standard_indentification_level_1  \
# #featureID
# 110.02020789262785_7.81588739061257                                NaN
# 496.3400991541585_5.156902118305356                                NaN
# 357.2789208085304_4.965391768541157                   Deoxycholic acid
# 373.2738491153533_3.899919847020934                  a-Muricholic acid
# 373.27386451947183_3.9615752818035452                b-Muricholic acid
#
#                                                                  _feature_id
# #featureID
# 110.02020789262785_7.81588739061257      110.02020789262785_7.81588739061257
# 496.3400991541585_5.156902118305356      496.3400991541585_5.156902118305356
# 357.2789208085304_4.965391768541157      357.2789208085304_4.965391768541157
# 373.2738491153533_3.899919847020934      373.2738491153533_3.899919847020934
# 373.27386451947183_3.9615752818035452  373.27386451947183_3.9615752818035452

# %%
# !open roc-metabites2.pdf

# %% [markdown]
# ## r plot

# %% [raw]
# library(ggplot2)
# d = read.table('common-imp-metabolites2.tsv', header=1, comment.char='', row.names=NULL, sep='\t')
# sm='loess'
# pdf('trend-metabolites2.pdf', width=7, height=3)
# for (i in unique(d$feature)) {
#   df=d[ d$feature == i, ]
#   taxon = as.character(df$taxonomy[1])
#   p = ggplot(df, aes(x=age, y=abundance, color=exposure_type)) +
#   geom_point() +
#   stat_smooth(data=subset(df, exposure_type='Air'), method=sm, se=T) +
#   stat_smooth(data=subset(df, exposure_type='IHH'), method=sm, se=T) +
#   facet_wrap( ~ genotype, scales = "free") +
#   # facet_grid( ~ genotype, scales = "free_x") +
#   ggtitle(taxon) +
#   theme(plot.title = element_text(size=10)) +
#   scale_y_continuous(name='abundance (%)', trans='log1p')
#   print(p)
# }
#  dev.off()

# %%
# !open trend-metabolites2.pdf

# %%
# !open trend-metabolites-colors.pdf
